# %% [markdown]
# ## Задание 1

# %% [markdown]
# *Вы провели эксперимент c упрощением формы заказа в магазине Утконос и получили результаты по метрике конверсий в покупку. Выберите метод оценки и оцените есть ли стат.значимые различия между конверсиями в двух группах при alpha = 5%. Дайте краткие рекомендации команде .Результаты: 1)Число юзеров в группах , которые заходили на сайт в период эксперимента: n1 = 15550 и n2 = 15550 . 2) Число юзеров в группах , которые совершили хотя бы одну покупку за период эксперимента: n1 = 164 и n2 = 228 3) Конверсии : conv1 = 1.05% conv2 = 1.47% .*

# %% [markdown]
# Нулевая гипотеза (H0): различий между конверсиями в группах нет (conv1 = conv2).
#
# Альтернативная гипотеза (H1): различия между конверсиями в группах есть (conv1 ≠ conv2).

# %% [markdown]
# Примем уровень значимости (α) = 0,05.
# Используя полученные данные, рассчитаем тестовую статистику:

# %% [markdown]
# z = (p2 - p1) / sqrt(p * (1-p) * (1/n1 + 1/n2))
#
# p = (x1 + x2) / (n1 + n2),
#
# x1 и x2 — количество конверсий в каждой группе, а p1 и p2 — коэффициенты конверсии в каждой группе.

# %%
import math

p1, p2 = 0.0105, 0.0147
x1, x2 = 164, 228
n1, n2 = 15550, 15550

p = (x1 + x2) / (n1 + n2)
z = (p2 - p1) / math.sqrt(p * (1 - p) * (1/n1 + 1/n2))
z
# Out:
# 3.3196406865514425

# %% [markdown]
# Критическое значение z при α=5% и двухсторонней альтернативе равно 1.96. Так как z-статистика больше критического значения, то мы можем отвергнуть нулевую гипотезу и сделать вывод о статистически значимых различиях между конверсиями в двух группах.
#
# ***Рекомендации команде:***
#
# Исходя из результатов эксперимента, можно сделать вывод, что упрощение формы заказа привело к увеличению конверсии в покупку. Рекомендуется внедрить упрощенную форму заказа на основной веб-сайт и отслеживать коэффициенты конверсии в течение более длительного периода, чтобы увидеть, сохраняется ли эффект.

# %% [markdown]
# ## Задание 2

# %% [markdown]
# *Сравниваем метрику конверсия в покупку. Размер выборки - 10000 элементов в каждой группе . Какой статистический критерий тут лучше всего подойдёт и почему ?*

# %% [markdown]
# Для сравнения метрики коэффициента конверсии между ***двумя группами с размером выборки 10 000 элементов в каждой*** подойдет t-критерий с двумя выборками. Это связано с тем, что размер выборки достаточно велик, а t-критерий предполагает, что данные распределены нормально. Кроме того, t-критерий устойчив к нарушениям предположений о нормальности, когда размер выборки достаточно велик. Критерий Стьюдента также обычно используется для сравнения средних значений двух групп и может обеспечить доверительный интервал для разницы в средних значениях. Таким образом, двухвыборочный t-критерий был бы лучшим статистическим тестом для использования в этом случае.
